# %% [markdown]
# # 4.10 Part 1 - Finalise database for customer segmentation

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Import libraries
# #### 2. Import data
# #### 3. Data security
# #### 4. Create regional segmentation
# #### 5. Create exclusion flag for low-activity customers
# #### 6. Export dataframes

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import data

# %%
# project folder path

path = r'C:\Users\Odette\Desktop\CareerFoundry\Immersion Courses\Course 4\Instacart Basket Analysis'

# %%
# import of orders_products data

final_df = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_final.pkl'))

# %%
final_df.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_last_order product_id  add_to_cart_order  reordered  \
# 0                      0        196                  1      False
# 1                     15        196                  1       True
# 2                     21        196                  1       True
# 3                     29        196                  1       True
# 4                     28        196                  1       True
#
#   product_name  ... median_order_days   order_frequency  gender    state age  \
# 0         Soda  ...              20.0  Regular customer  Female  Alabama  31
# 1         Soda  ...              20.0  Regular customer  Female  Alabama  31
# 2         Soda  ...              20.0  Regular customer  Female  Alabama  31
# 3         Soda  ...              20.0  Regular customer  Female  Alabama  31
# 4         Soda  ...              20.0  Regular customer  Female  Alabama  31
#
#   date_joined  n_dependants fam_status  income _merge
# 0  2019-02-17             3    married   40423   both
# 1  2019-02-17             3    married   40423   both
# 2  2019-02-17             3    married   40423   both
# 3  2019-02-17             3    married   40423   both
# 4  2019-02-17             3    married   40423   both
#
# [5 rows x 30 columns]

# %%
final_df.tail()
# Out:
#          order_id user_id  order_number  orders_day_of_week  \
# 32404854   156685  106143            26                   4
# 32404855   484769   66343             1                   6
# 32404856  1561557   66343             2                   1
# 32404857   276317   66343             3                   6
# 32404858  2922475   66343             4                   1
#
#           order_hour_of_day  days_since_last_order product_id  \
# 32404854                 23                      5      19675
# 32404855                 11                      0      47210
# 32404856                 11                     30      47210
# 32404857                 15                     19      47210
# 32404858                 12                     30      47210
#
#           add_to_cart_order  reordered                 product_name  ...  \
# 32404854                  1       True  Organic Raspberry Black Tea  ...
# 32404855                  1      False  Fresh Farmed Tilapia Fillet  ...
# 32404856                  1       True  Fresh Farmed Tilapia Fillet  ...
# 32404857                  1       True  Fresh Farmed Tilapia Fillet  ...
# 32404858                  1       True  Fresh Farmed Tilapia Fillet  ...
#
#          median_order_days        order_frequency  gender      state age  \
# 32404854               6.5      Frequent customer    Male     Hawaii  25
# 32404855              24.5  Non-frequent customer  Female  Tennessee  22
# 32404856              24.5  Non-frequent customer  Female  Tennessee  22
# 32404857              24.5  Non-frequent customer  Female  Tennessee  22
# 32404858              24.5  Non-frequent customer  Female  Tennessee  22
#
#          date_joined  n_dependants fam_status  income _merge
# 32404854  2017-05-26             0     single   53755   both
# 32404855  2017-09-12             3    married   46151   both
# 32404856  2017-09-12             3    married   46151   both
# 32404857  2017-09-12             3    married   46151   both
# 32404858  2017-09-12             3    married   46151   both
#
# [5 rows x 30 columns]

# %%
final_df.shape
# Out:
# (32404859, 30)

# %% [markdown]
# # Data security

# %% [markdown]
# The customers dataset, which was merged with the final_df dataframe, contained personally identifiable information (PII) in the form of first and last names. However, these columns were removed as part of the data cleansing process of the customers dataset. There is no other PII in the final_df dataframe. As well as removing all PII, all data has been stored and accessed safely, and no sensitive information has been distributed outside of the network.

# %% [markdown]
# # Create regional segmentation

# %%
# create a flag for Northeast region in new region column

final_df.loc[final_df['state'].isin(['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey']), 'region'] = 'Northeast'

# %%
# create a flag for Midwest region in new region column

final_df.loc[final_df['state'].isin(['Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri']), 'region'] = 'Midwest'

# %%
# create a flag for South region in new region column

final_df.loc[final_df['state'].isin(['Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana']), 'region'] = 'South'

# %%
# create a flag for West region in new region column

final_df.loc[final_df['state'].isin(['Idaho', 'Montana', 'Wyoming', 'Nevada', 'Utah', 'Colorado', 'Arizona', 'New Mexico', 'Alaska', 'Washington', 'Oregon', 'California', 'Hawaii']), 'region'] = 'West'

# %%
final_df['region'].value_counts(dropna = False)
# Out:
# South        10791885
# West          8292913
# Midwest       7597325
# Northeast     5722736
# Name: region, dtype: int64

# %%
# remove row limit to enable checking the data

pd.options.display.max_rows = None

# %%
# head results just for user_id, state & region

final_df[['user_id', 'state', 'region']].head(10)
# Out:
#   user_id    state region
# 0       1  Alabama  South
# 1       1  Alabama  South
# 2       1  Alabama  South
# 3       1  Alabama  South
# 4       1  Alabama  South
# 5       1  Alabama  South
# 6       1  Alabama  South
# 7       1  Alabama  South
# 8       1  Alabama  South
# 9       1  Alabama  South

# %%
# tail results just for user_id, state & region

final_df[['user_id', 'state', 'region']].tail(10)
# Out:
#          user_id      state region
# 32404849  106143     Hawaii   West
# 32404850  106143     Hawaii   West
# 32404851  106143     Hawaii   West
# 32404852  106143     Hawaii   West
# 32404853  106143     Hawaii   West
# 32404854  106143     Hawaii   West
# 32404855   66343  Tennessee  South
# 32404856   66343  Tennessee  South
# 32404857   66343  Tennessee  South
# 32404858   66343  Tennessee  South

# %%
# crosstab of region & loyalty_flag

crosstab = pd.crosstab(final_df['region'], final_df['loyalty_flag'], dropna = False)

# %%
# check crosstab analysis results

crosstab
# Out:
# loyalty_flag  Loyal customer  New customer  Regular customer
# region
# Midwest              2373774       1472573           3750978
# Northeast            1841785       1100207           2780744
# South                3405844       2074410           5311631
# West                 2662690       1596800           4033423

# %% [markdown]
# There is a difference in spending habits between the regions. The 'South' region is the most populous and also accounts for the most high and low spenders. The 'Northeast' region is the least populous and accounts for the least high and low spenders. However, the 'Midwest' has the highest proportion of its population being high spenders at 2.05%, followed by 'South' with 1.94%, 'West' with 1.93%, and 'Northeast' with 1.89%.

# %%
crosstab.to_clipboard()

# %% [markdown]
# # Create exclusion flag for low-activity customers

# %%
# create a flag for low-activity customers based on less than 5 orders

final_df.loc[final_df['max_order'] < 5, 'exclusion_flag'] = 'Low-activity Customer'

# %%
# create a flag for high-activity customers based on 5 or more orders

final_df.loc[final_df['max_order'] >= 5, 'exclusion_flag'] = 'Frequent Customer'

# %%
# tail results just for max_order & exclusion_flag

final_df[['max_order', 'exclusion_flag']].tail(10)
# Out:
#           max_order         exclusion_flag
# 32404849         26      Frequent Customer
# 32404850         26      Frequent Customer
# 32404851         26      Frequent Customer
# 32404852         26      Frequent Customer
# 32404853         26      Frequent Customer
# 32404854         26      Frequent Customer
# 32404855          4  Low-activity Customer
# 32404856          4  Low-activity Customer
# 32404857          4  Low-activity Customer
# 32404858          4  Low-activity Customer

# %%
final_df['exclusion_flag'].value_counts(dropna = False)
# Out:
# Frequent Customer        30964564
# Low-activity Customer     1440295
# Name: exclusion_flag, dtype: int64

# %%
# check dtype of new variables

final_df[['region', 'exclusion_flag']].dtypes
# Out:
# region            object
# exclusion_flag    object
# dtype: object

# %%
# convert the region & exclusion column to category format

final_df[['region', 'exclusion_flag']] = final_df[['region', 'exclusion_flag']].astype('category')

# %%
# creating new dataframe only showing Low-activity Customer

low_act_df = final_df[final_df['exclusion_flag'] == 'Low-activity Customer']

# %%
low_act_df.head(40)
# Out:
#      order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 1510   520620     120             1                   3                 11
# 1511  3273029     120             3                   2                  8
# 1512   520620     120             1                   3                 11
# 1513  3273029     120             3                   2                  8
# 1514   520620     120             1                   3                 11
# 1515   906054     120             2                   4                  7
# 1516  3273029     120             3                   2                  8
# 3855  3226575     360             1                   5                 12
# 3856  3046940     360             2                   2                  8
# 3857  2300993     360             3                   1                 13
# 3858  3226575     360             1                   5                 12
# 3859  2300993     360             3                   1                 13
# 3860  3226575     360             1                   5                 12
# 3861  3046940     360             2                   2                  8
# 3862  2300993     360             3                   1                 13
# 3863  3226575     360             1                   5                 12
# 3864  3046940     360             2                   2                  8
# 3865  3046940     360             2                   2                  8
# 3866  3226575     360             1                   5                 12
# 3867  3046940     360             2                   2                  8
# 3868  3046940     360             2                   2                  8
# 3869  2300993     360             3                   1                 13
# 3870  2300993     360             3                   1                 13
# 3871  1469869     377             3                   5                 17
# 3872  3371122     377             1                   3                 17
# 3873  3371122     377             1                   3                 17
# 3874   994985     377             2                   2                 12
# 3875  1469869     377             3                   5                 17
# 3876  3371122     377             1                   3                 17
# 3877  1469869     377             3                   5                 17
# 3878  3371122     377             1                   3                 17
# 3879   994985     377             2                   2                 12
# 3880  3371122     377             1                   3                 17
# 3881   994985     377             2                   2                 12
# 3882  1469869     377             3                   5                 17
# 3883  3371122     377             1                   3                 17
# 3884   994985     377             2                   2                 12
# 3885   994985     377             2                   2                 12
# 3886  3371122     377             1                   3                 17
# 3887   994985     377             2                   2                 12
#
#       days_since_last_order product_id  add_to_cart_order  reordered  \
# 1510                      0        196                  2      False
# 1511                     19        196                  2       True
# 1512                      0      46149                  1      False
# 1513                     19      46149                  1       True
# 1514                      0      26348                  3      False
# 1515                     15      31102                  1      False
# 1516                     19      31102                  3       True
# 3855                      0        196                  1      False
# 3856                      4       5322                  3      False
# 3857                      6       5322                  2       True
# 3858                      0      41406                  5      False
# 3859                      6      28155                  3      False
# 3860                      0      40910                  3      False
# 3861                      4      18095                  4      False
# 3862                      6      18095                  5       True
# 3863                      0      43556                  2      False
# 3864                      4      32285                  5      False
# 3865                      4      17022                  6      False
# 3866                      0       3039                  4      False
# 3867                      4      25630                  1      False
# 3868                      4      19376                  2      False
# 3869                      6      19376                  1       True
# 3870                      6      31716                  4      False
# 3871                      3        196                  9      False
# 3872                      0      16797                  5      False
# 3873                      0      24852                  6      False
# 3874                     30      24852                  2       True
# 3875                      3      47209                  2      False
# 3876                      0      39190                  7      False
# 3877                      3       1200                  6      False
# 3878                      0      21573                  1      False
# 3879                     30      21573                  9       True
# 3880                      0      38293                  4      False
# 3881                     30       8424                  4      False
# 3882                      3      47626                  8      False
# 3883                      0      24184                 10      False
# 3884                     30      43789                  5      False
# 3885                     30      23219                  8      False
# 3886                      0      17795                  9      False
# 3887                     30      23341                  1      False
#
#                                            product_name  ...  gender  \
# 1510                                               Soda  ...  Female
# 1511                                               Soda  ...  Female
# 1512                                  Zero Calorie Cola  ...  Female
# 1513                                  Zero Calorie Cola  ...  Female
# 1514                           Mixed Fruit Fruit Snacks  ...  Female
# 1515                            Sugar Free Energy Drink  ...  Female
# 1516                            Sugar Free Energy Drink  ...  Female
# 3855                                               Soda  ...    Male
# 3856  Gluten Free Dark Chocolate Chunk Chewy with a ...  ...    Male
# 3857  Gluten Free Dark Chocolate Chunk Chewy with a ...  ...    Male
# 3858                                        Orange Soda  ...    Male
# 3859                                 Premium Lager Beer  ...    Male
# 3860                                          Root Beer  ...    Male
# 3861                     Gluten Free Whole Grain Bagels  ...    Male
# 3862                     Gluten Free Whole Grain Bagels  ...    Male
# 3863                               Diet Lemon Lime Soda  ...    Male
# 3864                 Gluten Free Cinnamon Raisin Bagels  ...    Male
# 3865                                       Elbows Pasta  ...    Male
# 3866                                   Wild Cherry Cola  ...    Male
# 3867         Healthy Grains Fiber Cinnamon Oat Clusters  ...    Male
# 3868                 Gluten Free Crunchy Vanilla Cereal  ...    Male
# 3869                 Gluten Free Crunchy Vanilla Cereal  ...    Male
# 3870                                    312 Urban Wheat  ...    Male
# 3871                                               Soda  ...  Female
# 3872                                       Strawberries  ...  Female
# 3873                                             Banana  ...  Female
# 3874                                             Banana  ...  Female
# 3875                               Organic Hass Avocado  ...  Female
# 3876                    Vanilla Unsweetened Almond Milk  ...  Female
# 3877                  Vegetable Classics Vegetable Soup  ...  Female
# 3878                            Roasted Pine Nut Hummus  ...  Female
# 3879                            Roasted Pine Nut Hummus  ...  Female
# 3880                               Ground Turkey Breast  ...  Female
# 3881                                     Broccoli Crown  ...  Female
# 3882                                        Large Lemon  ...  Female
# 3883                                        Red Peppers  ...  Female
# 3884                                      Organic Basil  ...  Female
# 3885                                Nutz Over Chocolate  ...  Female
# 3886                         Organic Green Leaf Lettuce  ...  Female
# 3887                                Large Grade AA Eggs  ...  Female
#
#          state  age date_joined n_dependants fam_status  income _merge  \
# 1510  Kentucky   54  2017-03-02            2    married   99219   both
# 1511  Kentucky   54  2017-03-02            2    married   99219   both
# 1512  Kentucky   54  2017-03-02            2    married   99219   both
# 1513  Kentucky   54  2017-03-02            2    married   99219   both
# 1514  Kentucky   54  2017-03-02            2    married   99219   both
# 1515  Kentucky   54  2017-03-02            2    married   99219   both
# 1516  Kentucky   54  2017-03-02            2    married   99219   both
# 3855   Arizona   46  2017-09-01            1    married  104257   both
# 3856   Arizona   46  2017-09-01            1    married  104257   both
# 3857   Arizona   46  2017-09-01            1    married  104257   both
# 3858   Arizona   46  2017-09-01            1    married  104257   both
# 3859   Arizona   46  2017-09-01            1    married  104257   both
# 3860   Arizona   46  2017-09-01            1    married  104257   both
# 3861   Arizona   46  2017-09-01            1    married  104257   both
# 3862   Arizona   46  2017-09-01            1    married  104257   both
# 3863   Arizona   46  2017-09-01            1    married  104257   both
# 3864   Arizona   46  2017-09-01            1    married  104257   both
# 3865   Arizona   46  2017-09-01            1    married  104257   both
# 3866   Arizona   46  2017-09-01            1    married  104257   both
# 3867   Arizona   46  2017-09-01            1    married  104257   both
# 3868   Arizona   46  2017-09-01            1    married  104257   both
# 3869   Arizona   46  2017-09-01            1    married  104257   both
# 3870   Arizona   46  2017-09-01            1    married  104257   both
# 3871     Maine   49  2018-11-25            2    married  108557   both
# 3872     Maine   49  2018-11-25            2    married  108557   both
# 3873     Maine   49  2018-11-25            2    married  108557   both
# 3874     Maine   49  2018-11-25            2    married  108557   both
# 3875     Maine   49  2018-11-25            2    married  108557   both
# 3876     Maine   49  2018-11-25            2    married  108557   both
# 3877     Maine   49  2018-11-25            2    married  108557   both
# 3878     Maine   49  2018-11-25            2    married  108557   both
# 3879     Maine   49  2018-11-25            2    married  108557   both
# 3880     Maine   49  2018-11-25            2    married  108557   both
# 3881     Maine   49  2018-11-25            2    married  108557   both
# 3882     Maine   49  2018-11-25            2    married  108557   both
# 3883     Maine   49  2018-11-25            2    married  108557   both
# 3884     Maine   49  2018-11-25            2    married  108557   both
# 3885     Maine   49  2018-11-25            2    married  108557   both
# 3886     Maine   49  2018-11-25            2    married  108557   both
# 3887     Maine   49  2018-11-25            2    married  108557   both
#
#          region         exclusion_flag
# 1510      South  Low-activity Customer
# 1511      South  Low-activity Customer
# 1512      South  Low-activity Customer
# 1513      South  Low-activity Customer
# 1514      South  Low-activity Customer
# 1515      South  Low-activity Customer
# 1516      South  Low-activity Customer
# 3855       West  Low-activity Customer
# 3856       West  Low-activity Customer
# 3857       West  Low-activity Customer
# 3858       West  Low-activity Customer
# 3859       West  Low-activity Customer
# 3860       West  Low-activity Customer
# 3861       West  Low-activity Customer
# 3862       West  Low-activity Customer
# 3863       West  Low-activity Customer
# 3864       West  Low-activity Customer
# 3865       West  Low-activity Customer
# 3866       West  Low-activity Customer
# 3867       West  Low-activity Customer
# 3868       West  Low-activity Customer
# 3869       West  Low-activity Customer
# 3870       West  Low-activity Customer
# 3871  Northeast  Low-activity Customer
# 3872  Northeast  Low-activity Customer
# 3873  Northeast  Low-activity Customer
# 3874  Northeast  Low-activity Customer
# 3875  Northeast  Low-activity Customer
# 3876  Northeast  Low-activity Customer
# 3877  Northeast  Low-activity Customer
# 3878  Northeast  Low-activity Customer
# 3879  Northeast  Low-activity Customer
# 3880  Northeast  Low-activity Customer
# 3881  Northeast  Low-activity Customer
# 3882  Northeast  Low-activity Customer
# 3883  Northeast  Low-activity Customer
# 3884  Northeast  Low-activity Customer
# 3885  Northeast  Low-activity Customer
# 3886  Northeast  Low-activity Customer
# 3887  Northeast  Low-activity Customer
#
# [40 rows x 32 columns]

# %%
low_act_df.shape
# Out:
# (1440295, 32)

# %%
# creating new dataframe only including Frequent Customer

Insta_final_df = final_df[final_df['exclusion_flag'] == 'Frequent Customer']

# %%
Insta_final_df.head(10)
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
# 5  3367565       1             6                   2                  7
# 6   550135       1             7                   1                  9
# 7  3108588       1             8                   1                 14
# 8  2295261       1             9                   1                 16
# 9  2550362       1            10                   4                  8
#
#    days_since_last_order product_id  add_to_cart_order  reordered  \
# 0                      0        196                  1      False
# 1                     15        196                  1       True
# 2                     21        196                  1       True
# 3                     29        196                  1       True
# 4                     28        196                  1       True
# 5                     19        196                  1       True
# 6                     20        196                  1       True
# 7                     14        196                  2       True
# 8                      0        196                  4       True
# 9                     30        196                  1       True
#
#   product_name  ...  gender    state  age date_joined n_dependants fam_status  \
# 0         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 1         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 2         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 3         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 4         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 5         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 6         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 7         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 8         Soda  ...  Female  Alabama   31  2019-02-17            3    married
# 9         Soda  ...  Female  Alabama   31  2019-02-17            3    married
#
#    income _merge  region     exclusion_flag
# 0   40423   both   South  Frequent Customer
# 1   40423   both   South  Frequent Customer
# 2   40423   both   South  Frequent Customer
# 3   40423   both   South  Frequent Customer
# 4   40423   both   South  Frequent Customer
# 5   40423   both   South  Frequent Customer
# 6   40423   both   South  Frequent Customer
# 7   40423   both   South  Frequent Customer
# 8   40423   both   South  Frequent Customer
# 9   40423   both   South  Frequent Customer
#
# [10 rows x 32 columns]

# %%
Insta_final_df.shape
# Out:
# (30964564, 32)

# %% [markdown]
# # Export dataframes

# %%
# export low_act_df to pkl 
 
low_act_df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'low_activity_customers.pkl'))

# %%
# export Insta_final_df to pkl 
 
Insta_final_df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Instacart_final.pkl'))
