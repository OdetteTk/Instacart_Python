# %% [markdown]
# # 4.8 Grouping data & aggregating variables

# %% [markdown]
# ### This script contains:
#
# #### 1. Import libraries
# #### 2. Import data
# #### 3. Find the aggregated mean of the order_number column grouped by department_id
# #### 4. Create a loyalty flag for existing customers
# #### 5. Spending habits of customers
# #### 6. Low and high spenders
# #### 7. Frequent and non-frequent customers
# #### 8. Exporting final dataframe

# %% [markdown]
# # Import libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import data

# %%
# project folder path

path = r'C:\Users\Odette\Desktop\CareerFoundry\Immersion Courses\Course 4\Instacart Basket Analysis'

# %%
# import of orders_products_merged data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products1.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    0.0         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy        Average orders
# 1  Mid-range product      Least busy        Average orders
# 2  Mid-range product      Least busy           Most orders
# 3  Mid-range product      Least busy        Average orders
# 4  Mid-range product      Least busy           Most orders

# %% [markdown]
# # Find the aggregated mean of the order_number column grouped by department_id

# %%
# obtain the mean values for the “order_number” column (with agg function)

ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# This aggregation includes all 21 department id's, whereas the subset only contained 8 department id's. It includes all information, not just a sample

# %% [markdown]
# # Create a loyalty flag for existing customers

# %%
# creating a flag for customers with many orders

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    0.0         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc    busiest_days busiest_period_of_day  max_order
# 0  Mid-range product  Regularly busy        Average orders         10
# 1  Mid-range product      Least busy        Average orders         10
# 2  Mid-range product      Least busy           Most orders         10
# 3  Mid-range product      Least busy        Average orders         10
# 4  Mid-range product      Least busy           Most orders         10

# %%
# create flag for loyal customers (max_order over 40)

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# create flag for regular customers (max_order between 10 & 40)

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# create flag for loyal customers (max_order under 10)

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# head results just for user_id, loyalty_flag & order_number

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# # Spending habits of customers

# %%
# group by loyalty_flag to determine stats on price differences in the groups

ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# # Low and high spenders

# %%
# creating a flag for customers' average spend

ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    0.0         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0          0  ...       77              7     9.0    both  Mid-range product
# 1          1  ...       77              7     9.0    both  Mid-range product
# 2          1  ...       77              7     9.0    both  Mid-range product
# 3          1  ...       77              7     9.0    both  Mid-range product
# 4          1  ...       77              7     9.0    both  Mid-range product
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag average_spend
# 0  Regularly busy        Average orders        10  New customer      6.367797
# 1      Least busy        Average orders        10  New customer      6.367797
# 2      Least busy           Most orders        10  New customer      6.367797
# 3      Least busy        Average orders        10  New customer      6.367797
# 4      Least busy           Most orders        10  New customer      6.367797
#
# [5 rows x 21 columns]

# %%
# create flag for high spenders (average_spend 10 or over)

ords_prods_merge.loc[ords_prods_merge['average_spend'] >= 10, 'spending_type'] = 'High spender'

# %%
# create flag for low spenders (average_spend under 10)

ords_prods_merge.loc[ords_prods_merge['average_spend'] < 10, 'spending_type'] = 'Low spender'

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
# 15         209   2293453       19             2                   5
# 16         212   1973799       19             5                   6
# 17         214    532817       19             7                   4
# 18         232   1573906       21            10                   3
# 19         458   1593000       31            10                   3
# 20         465   2231262       31            17                   3
# 21         617   2580647       43             6                   4
# 22         620   2187180       43             9                   4
# 23         751   2497897       52             1                   1
# 24         752   1318871       52             2                   1
# 25         753   1261384       52             3                   1
# 26         755    580568       52             5                   2
# 27         757   2428073       52             7                   2
# 28         759    342306       52             9                   1
# 29         760   1520353       52            10                   2
# 30         761   2542086       52            11                   2
# 31         762    944694       52            12                   1
# 32         765   1268191       52            15                   2
# 33         767   1122089       52            17                   2
# 34         768   1498922       52            18                   2
# 35         769    180919       52            19                   3
# 36         771   2695875       52            21                   5
# 37        1022   3205960       67             1                   3
# 38        1023    970922       67             2                   1
# 39        1024    596585       67             3                   1
# 40        1025   2037087       67             4                   2
# 41        1026   2474111       67             5                   3
# 42        1027   1568481       67             6                   3
# 43        1029   2048527       67             8                   2
# 44        1030   2389031       67             9                   2
# 45        1031   2378562       67            10                   1
# 46        1032   1515698       67            11                   1
# 47        1033   1928050       67            12                   2
# 48        1034   1949274       67            13                   1
# 49        1035    551869       67            14                   1
# 50        1037    768572       67            16                   4
# 51        1039    150528       67            18                   5
# 52        1040     29758       67            19                   0
# 53        1042   1558976       67            21                   1
# 54        1043    863974       67            22                   1
# 55        1044   2308399       67            23                   1
# 56        1202   2759128       81             3                   1
# 57        1204   1812985       81             5                   2
# 58        1208   1889835       82             1                   3
# 59        1210    499460       82             3                   5
# 60        1211   2728456       82             4                   0
# 61        1213   2653743       82             6                   4
# 62        1216   1358880       82             9                   1
# 63        1217    343588       82            10                   2
# 64        1222   3034663       82            15                   2
# 65        1225    147262       82            18                   1
# 66        1226   3144004       82            19                   2
# 67        1480   2126069       98             3                   0
# 68        1484   2210120       98             7                   5
# 69        1486    681011       98             9                   3
# 70        1488   2846344       98            11                   4
# 71        1489    747431       98            12                   6
# 72        1490   2383054       98            13                   4
# 73        1491   1993729       98            14                   5
# 74        1608   1403849      109             3                   3
# 75        1744    520620      120             1                   3
# 76        1746   3273029      120             3                   2
# 77        2781   1861943      185             2                   1
# 78        2891   2040988      195             1                   1
# 79        2898   1680569      195             8                   1
# 80        2909    276171      195            19                   5
# 81        2912   2744976      195            22                   5
# 82        2915   2781919      195            25                   1
# 83        2921   1738718      195            31                   2
# 84        2924   3058369      195            34                   3
# 85        2927   1485596      195            37                   2
# 86        2930    417035      195            40                   3
# 87        2937   1615297      195            47                   5
# 88        2942   1765587      195            52                   3
# 89        2947    745908      195            57                   4
# 90        3451   2505656      222            17                   2
# 91        3472   3268370      222            38                   5
# 92        4667   2016711      290             9                   5
# 93        4686   2706088      290            28                   6
# 94        5551   1952286      331             6                   5
# 95        5895   3226575      360             1                   5
# 96        6137   1469869      377             3                   5
# 97        6259   1927023      387             2                   4
# 98        6740    858092      420             4                   1
# 99        6741    119314      420             5                   3
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                   8                    0.0         196                  1
# 1                   7                   15.0         196                  1
# 2                  12                   21.0         196                  1
# 3                   7                   29.0         196                  1
# 4                  15                   28.0         196                  1
# 5                   7                   19.0         196                  1
# 6                   9                   20.0         196                  1
# 7                  14                   14.0         196                  2
# 8                  16                    0.0         196                  4
# 9                   8                   30.0         196                  1
# 10                  9                    7.0         196                  2
# 11                 16                    8.0         196                  6
# 12                 11                    7.0         196                  1
# 13                  9                    7.0         196                  1
# 14                 10                   14.0         196                  1
# 15                 14                    6.0         196                  3
# 16                 12                    8.0         196                 15
# 17                 17                    6.0         196                  1
# 18                 10                    6.0         196                  2
# 19                  8                    7.0         196                 17
# 20                 11                    8.0         196                 14
# 21                 16                    4.0         196                  9
# 22                 12                    3.0         196                  1
# 23                  9                    0.0         196                  4
# 24                 10                    7.0         196                  5
# 25                 10                    7.0         196                  3
# 26                 10                    8.0         196                  6
# 27                  7                    8.0         196                  5
# 28                 11                    7.0         196                  5
# 29                 10                    8.0         196                  4
# 30                  9                    7.0         196                  3
# 31                 16                    6.0         196                  7
# 32                 11                    8.0         196                  3
# 33                 10                    6.0         196                  4
# 34                 10                   14.0         196                  6
# 35                  8                    8.0         196                  4
# 36                 10                   30.0         196                  1
# 37                 11                    0.0         196                  1
# 38                 15                    5.0         196                  2
# 39                 13                    7.0         196                  2
# 40                  9                    8.0         196                  1
# 41                 14                    8.0         196                  2
# 42                 12                    7.0         196                  2
# 43                 11                    7.0         196                  1
# 44                 14                    7.0         196                  1
# 45                 10                    6.0         196                  1
# 46                 11                    7.0         196                  1
# 47                 12                    8.0         196                  1
# 48                 10                    6.0         196                  1
# 49                  9                    7.0         196                  1
# 50                 10                    9.0         196                  1
# 51                 16                    4.0         196                  1
# 52                 14                    9.0         196                  2
# 53                  9                    5.0         196                  2
# 54                 11                   14.0         196                  3
# 55                 14                   14.0         196                  1
# 56                  9                   14.0         196                  2
# 57                 20                   30.0         196                  1
# 58                 15                    0.0         196                  6
# 59                 10                    5.0         196                  2
# 60                 11                   16.0         196                  1
# 61                  9                   13.0         196                  5
# 62                 10                   30.0         196                  1
# 63                 11                    1.0         196                  1
# 64                 11                   12.0         196                  1
# 65                 13                    7.0         196                  1
# 66                 15                    8.0         196                  1
# 67                  9                   25.0         196                  7
# 68                 14                    5.0         196                  1
# 69                  9                   30.0         196                  1
# 70                 13                   15.0         196                  2
# 71                 13                   30.0         196                  4
# 72                 11                   30.0         196                  1
# 73                  8                    8.0         196                  2
# 74                 17                    9.0         196                  5
# 75                 11                    0.0         196                  2
# 76                  8                   19.0         196                  2
# 77                 12                   25.0         196                 10
# 78                 14                    0.0         196                  2
# 79                  9                    4.0         196                  2
# 80                 11                    3.0         196                  2
# 81                 10                    7.0         196                  2
# 82                 14                    4.0         196                  1
# 83                  8                    4.0         196                  2
# 84                 10                    6.0         196                  2
# 85                 15                    0.0         196                  2
# 86                 16                    2.0         196                  2
# 87                 10                    2.0         196                  2
# 88                 12                    2.0         196                  3
# 89                 11                    3.0         196                  3
# 90                 12                    1.0         196                  2
# 91                 15                    1.0         196                  6
# 92                 19                    6.0         196                  8
# 93                 10                    7.0         196                 16
# 94                 16                   30.0         196                  8
# 95                 12                    0.0         196                  1
# 96                 17                    3.0         196                  9
# 97                 10                   22.0         196                  3
# 98                 19                   30.0         196                  2
# 99                 19                   16.0         196                  2
#
#     reordered  ... department_id  prices  _merge    price_range_loc  \
# 0           0  ...             7     9.0    both  Mid-range product
# 1           1  ...             7     9.0    both  Mid-range product
# 2           1  ...             7     9.0    both  Mid-range product
# 3           1  ...             7     9.0    both  Mid-range product
# 4           1  ...             7     9.0    both  Mid-range product
# 5           1  ...             7     9.0    both  Mid-range product
# 6           1  ...             7     9.0    both  Mid-range product
# 7           1  ...             7     9.0    both  Mid-range product
# 8           1  ...             7     9.0    both  Mid-range product
# 9           1  ...             7     9.0    both  Mid-range product
# 10          0  ...             7     9.0    both  Mid-range product
# 11          1  ...             7     9.0    both  Mid-range product
# 12          1  ...             7     9.0    both  Mid-range product
# 13          1  ...             7     9.0    both  Mid-range product
# 14          1  ...             7     9.0    both  Mid-range product
# 15          0  ...             7     9.0    both  Mid-range product
# 16          1  ...             7     9.0    both  Mid-range product
# 17          1  ...             7     9.0    both  Mid-range product
# 18          0  ...             7     9.0    both  Mid-range product
# 19          0  ...             7     9.0    both  Mid-range product
# 20          1  ...             7     9.0    both  Mid-range product
# 21          0  ...             7     9.0    both  Mid-range product
# 22          1  ...             7     9.0    both  Mid-range product
# 23          0  ...             7     9.0    both  Mid-range product
# 24          1  ...             7     9.0    both  Mid-range product
# 25          1  ...             7     9.0    both  Mid-range product
# 26          1  ...             7     9.0    both  Mid-range product
# 27          1  ...             7     9.0    both  Mid-range product
# 28          1  ...             7     9.0    both  Mid-range product
# 29          1  ...             7     9.0    both  Mid-range product
# 30          1  ...             7     9.0    both  Mid-range product
# 31          1  ...             7     9.0    both  Mid-range product
# 32          1  ...             7     9.0    both  Mid-range product
# 33          1  ...             7     9.0    both  Mid-range product
# 34          1  ...             7     9.0    both  Mid-range product
# 35          1  ...             7     9.0    both  Mid-range product
# 36          1  ...             7     9.0    both  Mid-range product
# 37          0  ...             7     9.0    both  Mid-range product
# 38          1  ...             7     9.0    both  Mid-range product
# 39          1  ...             7     9.0    both  Mid-range product
# 40          1  ...             7     9.0    both  Mid-range product
# 41          1  ...             7     9.0    both  Mid-range product
# 42          1  ...             7     9.0    both  Mid-range product
# 43          1  ...             7     9.0    both  Mid-range product
# 44          1  ...             7     9.0    both  Mid-range product
# 45          1  ...             7     9.0    both  Mid-range product
# 46          1  ...             7     9.0    both  Mid-range product
# 47          1  ...             7     9.0    both  Mid-range product
# 48          1  ...             7     9.0    both  Mid-range product
# 49          1  ...             7     9.0    both  Mid-range product
# 50          1  ...             7     9.0    both  Mid-range product
# 51          1  ...             7     9.0    both  Mid-range product
# 52          1  ...             7     9.0    both  Mid-range product
# 53          1  ...             7     9.0    both  Mid-range product
# 54          1  ...             7     9.0    both  Mid-range product
# 55          1  ...             7     9.0    both  Mid-range product
# 56          0  ...             7     9.0    both  Mid-range product
# 57          1  ...             7     9.0    both  Mid-range product
# 58          0  ...             7     9.0    both  Mid-range product
# 59          1  ...             7     9.0    both  Mid-range product
# 60          1  ...             7     9.0    both  Mid-range product
# 61          1  ...             7     9.0    both  Mid-range product
# 62          1  ...             7     9.0    both  Mid-range product
# 63          1  ...             7     9.0    both  Mid-range product
# 64          1  ...             7     9.0    both  Mid-range product
# 65          1  ...             7     9.0    both  Mid-range product
# 66          1  ...             7     9.0    both  Mid-range product
# 67          0  ...             7     9.0    both  Mid-range product
# 68          1  ...             7     9.0    both  Mid-range product
# 69          1  ...             7     9.0    both  Mid-range product
# 70          1  ...             7     9.0    both  Mid-range product
# 71          1  ...             7     9.0    both  Mid-range product
# 72          1  ...             7     9.0    both  Mid-range product
# 73          1  ...             7     9.0    both  Mid-range product
# 74          0  ...             7     9.0    both  Mid-range product
# 75          0  ...             7     9.0    both  Mid-range product
# 76          1  ...             7     9.0    both  Mid-range product
# 77          0  ...             7     9.0    both  Mid-range product
# 78          0  ...             7     9.0    both  Mid-range product
# 79          1  ...             7     9.0    both  Mid-range product
# 80          1  ...             7     9.0    both  Mid-range product
# 81          1  ...             7     9.0    both  Mid-range product
# 82          1  ...             7     9.0    both  Mid-range product
# 83          1  ...             7     9.0    both  Mid-range product
# 84          1  ...             7     9.0    both  Mid-range product
# 85          1  ...             7     9.0    both  Mid-range product
# 86          1  ...             7     9.0    both  Mid-range product
# 87          1  ...             7     9.0    both  Mid-range product
# 88          1  ...             7     9.0    both  Mid-range product
# 89          1  ...             7     9.0    both  Mid-range product
# 90          0  ...             7     9.0    both  Mid-range product
# 91          1  ...             7     9.0    both  Mid-range product
# 92          0  ...             7     9.0    both  Mid-range product
# 93          1  ...             7     9.0    both  Mid-range product
# 94          0  ...             7     9.0    both  Mid-range product
# 95          0  ...             7     9.0    both  Mid-range product
# 96          0  ...             7     9.0    both  Mid-range product
# 97          0  ...             7     9.0    both  Mid-range product
# 98          0  ...             7     9.0    both  Mid-range product
# 99          1  ...             7     9.0    both  Mid-range product
#
#       busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy        Average orders        10      New customer
# 1       Least busy        Average orders        10      New customer
# 2       Least busy           Most orders        10      New customer
# 3       Least busy        Average orders        10      New customer
# 4       Least busy           Most orders        10      New customer
# 5   Regularly busy        Average orders        10      New customer
# 6     Busiest days           Most orders        10      New customer
# 7     Busiest days           Most orders        10      New customer
# 8     Busiest days           Most orders        10      New customer
# 9       Least busy        Average orders        10      New customer
# 10    Busiest days           Most orders        22  Regular customer
# 11  Regularly busy           Most orders        22  Regular customer
# 12  Regularly busy           Most orders        22  Regular customer
# 13    Busiest days           Most orders        22  Regular customer
# 14    Busiest days           Most orders        22  Regular customer
# 15  Regularly busy           Most orders         9      New customer
# 16  Regularly busy           Most orders         9      New customer
# 17      Least busy           Most orders         9      New customer
# 18      Least busy           Most orders        33  Regular customer
# 19      Least busy        Average orders        20  Regular customer
# 20      Least busy           Most orders        20  Regular customer
# 21      Least busy           Most orders        11  Regular customer
# 22      Least busy           Most orders        11  Regular customer
# 23    Busiest days           Most orders        27  Regular customer
# 24    Busiest days           Most orders        27  Regular customer
# 25    Busiest days           Most orders        27  Regular customer
# 26  Regularly busy           Most orders        27  Regular customer
# 27  Regularly busy        Average orders        27  Regular customer
# 28    Busiest days           Most orders        27  Regular customer
# 29  Regularly busy           Most orders        27  Regular customer
# 30  Regularly busy           Most orders        27  Regular customer
# 31    Busiest days           Most orders        27  Regular customer
# 32  Regularly busy           Most orders        27  Regular customer
# 33  Regularly busy           Most orders        27  Regular customer
# 34  Regularly busy           Most orders        27  Regular customer
# 35      Least busy        Average orders        27  Regular customer
# 36  Regularly busy           Most orders        27  Regular customer
# 37      Least busy           Most orders        24  Regular customer
# 38    Busiest days           Most orders        24  Regular customer
# 39    Busiest days           Most orders        24  Regular customer
# 40  Regularly busy           Most orders        24  Regular customer
# 41      Least busy           Most orders        24  Regular customer
# 42      Least busy           Most orders        24  Regular customer
# 43  Regularly busy           Most orders        24  Regular customer
# 44  Regularly busy           Most orders        24  Regular customer
# 45    Busiest days           Most orders        24  Regular customer
# 46    Busiest days           Most orders        24  Regular customer
# 47  Regularly busy           Most orders        24  Regular customer
# 48    Busiest days           Most orders        24  Regular customer
# 49    Busiest days           Most orders        24  Regular customer
# 50      Least busy           Most orders        24  Regular customer
# 51  Regularly busy           Most orders        24  Regular customer
# 52    Busiest days           Most orders        24  Regular customer
# 53    Busiest days           Most orders        24  Regular customer
# 54    Busiest days           Most orders        24  Regular customer
# 55    Busiest days           Most orders        24  Regular customer
# 56    Busiest days           Most orders         7      New customer
# 57  Regularly busy        Average orders         7      New customer
# 58      Least busy           Most orders        19  Regular customer
# 59  Regularly busy           Most orders        19  Regular customer
# 60    Busiest days           Most orders        19  Regular customer
# 61      Least busy           Most orders        19  Regular customer
# 62    Busiest days           Most orders        19  Regular customer
# 63  Regularly busy           Most orders        19  Regular customer
# 64  Regularly busy           Most orders        19  Regular customer
# 65    Busiest days           Most orders        19  Regular customer
# 66  Regularly busy           Most orders        19  Regular customer
# 67    Busiest days           Most orders        14  Regular customer
# 68  Regularly busy           Most orders        14  Regular customer
# 69      Least busy           Most orders        14  Regular customer
# 70      Least busy           Most orders        14  Regular customer
# 71  Regularly busy           Most orders        14  Regular customer
# 72      Least busy           Most orders        14  Regular customer
# 73  Regularly busy        Average orders        14  Regular customer
# 74      Least busy           Most orders         6      New customer
# 75      Least busy           Most orders         3      New customer
# 76  Regularly busy        Average orders         3      New customer
# 77    Busiest days           Most orders         6      New customer
# 78    Busiest days           Most orders        58    Loyal customer
# 79    Busiest days           Most orders        58    Loyal customer
# 80  Regularly busy           Most orders        58    Loyal customer
# 81  Regularly busy           Most orders        58    Loyal customer
# 82    Busiest days           Most orders        58    Loyal customer
# 83  Regularly busy        Average orders        58    Loyal customer
# 84      Least busy           Most orders        58    Loyal customer
# 85  Regularly busy           Most orders        58    Loyal customer
# 86      Least busy           Most orders        58    Loyal customer
# 87  Regularly busy           Most orders        58    Loyal customer
# 88      Least busy           Most orders        58    Loyal customer
# 89      Least busy           Most orders        58    Loyal customer
# 90  Regularly busy           Most orders        70    Loyal customer
# 91  Regularly busy           Most orders        70    Loyal customer
# 92  Regularly busy        Average orders        51    Loyal customer
# 93  Regularly busy           Most orders        51    Loyal customer
# 94  Regularly busy           Most orders         8      New customer
# 95  Regularly busy           Most orders         3      New customer
# 96  Regularly busy           Most orders         3      New customer
# 97      Least busy           Most orders         8      New customer
# 98    Busiest days        Average orders        22  Regular customer
# 99      Least busy        Average orders        22  Regular customer
#
#     average_spend spending_type
# 0        6.367797   Low spender
# 1        6.367797   Low spender
# 2        6.367797   Low spender
# 3        6.367797   Low spender
# 4        6.367797   Low spender
# 5        6.367797   Low spender
# 6        6.367797   Low spender
# 7        6.367797   Low spender
# 8        6.367797   Low spender
# 9        6.367797   Low spender
# 10       3.980556   Low spender
# 11       3.980556   Low spender
# 12       3.980556   Low spender
# 13       3.980556   Low spender
# 14       3.980556   Low spender
# 15       8.372059   Low spender
# 16       8.372059   Low spender
# 17       8.372059   Low spender
# 18       7.012683   Low spender
# 19       8.137793   Low spender
# 20       8.137793   Low spender
# 21       7.444898   Low spender
# 22       7.444898   Low spender
# 23       6.356287   Low spender
# 24       6.356287   Low spender
# 25       6.356287   Low spender
# 26       6.356287   Low spender
# 27       6.356287   Low spender
# 28       6.356287   Low spender
# 29       6.356287   Low spender
# 30       6.356287   Low spender
# 31       6.356287   Low spender
# 32       6.356287   Low spender
# 33       6.356287   Low spender
# 34       6.356287   Low spender
# 35       6.356287   Low spender
# 36       6.356287   Low spender
# 37       7.656790   Low spender
# 38       7.656790   Low spender
# 39       7.656790   Low spender
# 40       7.656790   Low spender
# 41       7.656790   Low spender
# 42       7.656790   Low spender
# 43       7.656790   Low spender
# 44       7.656790   Low spender
# 45       7.656790   Low spender
# 46       7.656790   Low spender
# 47       7.656790   Low spender
# 48       7.656790   Low spender
# 49       7.656790   Low spender
# 50       7.656790   Low spender
# 51       7.656790   Low spender
# 52       7.656790   Low spender
# 53       7.656790   Low spender
# 54       7.656790   Low spender
# 55       7.656790   Low spender
# 56       8.165385   Low spender
# 57       8.165385   Low spender
# 58       6.441221   Low spender
# 59       6.441221   Low spender
# 60       6.441221   Low spender
# 61       6.441221   Low spender
# 62       6.441221   Low spender
# 63       6.441221   Low spender
# 64       6.441221   Low spender
# 65       6.441221   Low spender
# 66       6.441221   Low spender
# 67       8.028000   Low spender
# 68       8.028000   Low spender
# 69       8.028000   Low spender
# 70       8.028000   Low spender
# 71       8.028000   Low spender
# 72       8.028000   Low spender
# 73       8.028000   Low spender
# 74       5.850725   Low spender
# 75       9.385714   Low spender
# 76       9.385714   Low spender
# 77       7.715000   Low spender
# 78       7.149730   Low spender
# 79       7.149730   Low spender
# 80       7.149730   Low spender
# 81       7.149730   Low spender
# 82       7.149730   Low spender
# 83       7.149730   Low spender
# 84       7.149730   Low spender
# 85       7.149730   Low spender
# 86       7.149730   Low spender
# 87       7.149730   Low spender
# 88       7.149730   Low spender
# 89       7.149730   Low spender
# 90       6.862397   Low spender
# 91       6.862397   Low spender
# 92       7.285597   Low spender
# 93       7.285597   Low spender
# 94       7.705128   Low spender
# 95      10.006250  High spender
# 96       8.496552   Low spender
# 97       7.396610   Low spender
# 98       7.387805   Low spender
# 99       7.387805   Low spender
#
# [100 rows x 22 columns]

# %% [markdown]
# # Frequent and non-frequent customers

# %%
# create a flag for customers order frequency based on median of days_since_prior_order 

ords_prods_merge['median_order_days'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                   8                    0.0         196                  1
# 1                   7                   15.0         196                  1
# 2                  12                   21.0         196                  1
# 3                   7                   29.0         196                  1
# 4                  15                   28.0         196                  1
# 5                   7                   19.0         196                  1
# 6                   9                   20.0         196                  1
# 7                  14                   14.0         196                  2
# 8                  16                    0.0         196                  4
# 9                   8                   30.0         196                  1
# 10                  9                    7.0         196                  2
# 11                 16                    8.0         196                  6
# 12                 11                    7.0         196                  1
# 13                  9                    7.0         196                  1
# 14                 10                   14.0         196                  1
#
#     reordered  ... prices  _merge    price_range_loc    busiest_days  \
# 0           0  ...    9.0    both  Mid-range product  Regularly busy
# 1           1  ...    9.0    both  Mid-range product      Least busy
# 2           1  ...    9.0    both  Mid-range product      Least busy
# 3           1  ...    9.0    both  Mid-range product      Least busy
# 4           1  ...    9.0    both  Mid-range product      Least busy
# 5           1  ...    9.0    both  Mid-range product  Regularly busy
# 6           1  ...    9.0    both  Mid-range product    Busiest days
# 7           1  ...    9.0    both  Mid-range product    Busiest days
# 8           1  ...    9.0    both  Mid-range product    Busiest days
# 9           1  ...    9.0    both  Mid-range product      Least busy
# 10          0  ...    9.0    both  Mid-range product    Busiest days
# 11          1  ...    9.0    both  Mid-range product  Regularly busy
# 12          1  ...    9.0    both  Mid-range product  Regularly busy
# 13          1  ...    9.0    both  Mid-range product    Busiest days
# 14          1  ...    9.0    both  Mid-range product    Busiest days
#
#    busiest_period_of_day max_order      loyalty_flag average_spend  \
# 0         Average orders        10      New customer      6.367797
# 1         Average orders        10      New customer      6.367797
# 2            Most orders        10      New customer      6.367797
# 3         Average orders        10      New customer      6.367797
# 4            Most orders        10      New customer      6.367797
# 5         Average orders        10      New customer      6.367797
# 6            Most orders        10      New customer      6.367797
# 7            Most orders        10      New customer      6.367797
# 8            Most orders        10      New customer      6.367797
# 9         Average orders        10      New customer      6.367797
# 10           Most orders        22  Regular customer      3.980556
# 11           Most orders        22  Regular customer      3.980556
# 12           Most orders        22  Regular customer      3.980556
# 13           Most orders        22  Regular customer      3.980556
# 14           Most orders        22  Regular customer      3.980556
#
#     spending_type median_order_days
# 0     Low spender              20.0
# 1     Low spender              20.0
# 2     Low spender              20.0
# 3     Low spender              20.0
# 4     Low spender              20.0
# 5     Low spender              20.0
# 6     Low spender              20.0
# 7     Low spender              20.0
# 8     Low spender              20.0
# 9     Low spender              20.0
# 10    Low spender               8.0
# 11    Low spender               8.0
# 12    Low spender               8.0
# 13    Low spender               8.0
# 14    Low spender               8.0
#
# [15 rows x 23 columns]

# %%
# create flag for non-frequent customers (order_frequency over 20)

ords_prods_merge.loc[ords_prods_merge['median_order_days'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
# create flag for regular customers (order_frequency between 10 & 20)

ords_prods_merge.loc[(ords_prods_merge['median_order_days'] > 10) & (ords_prods_merge['median_order_days'] <= 20), 'order_frequency'] = 'Regular customer'

# %%
# create flag for frequent customers (order_frequency under 10)

ords_prods_merge.loc[ords_prods_merge['median_order_days'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10         144   2968173       15            15                   1
# 11         146   1870022       15            17                   2
# 12         147   1911383       15            18                   2
# 13         150   2715276       15            21                   1
# 14         151    487368       15            22                   1
# 15         209   2293453       19             2                   5
# 16         212   1973799       19             5                   6
# 17         214    532817       19             7                   4
# 18         232   1573906       21            10                   3
# 19         458   1593000       31            10                   3
# 20         465   2231262       31            17                   3
# 21         617   2580647       43             6                   4
# 22         620   2187180       43             9                   4
# 23         751   2497897       52             1                   1
# 24         752   1318871       52             2                   1
# 25         753   1261384       52             3                   1
# 26         755    580568       52             5                   2
# 27         757   2428073       52             7                   2
# 28         759    342306       52             9                   1
# 29         760   1520353       52            10                   2
# 30         761   2542086       52            11                   2
# 31         762    944694       52            12                   1
# 32         765   1268191       52            15                   2
# 33         767   1122089       52            17                   2
# 34         768   1498922       52            18                   2
# 35         769    180919       52            19                   3
# 36         771   2695875       52            21                   5
# 37        1022   3205960       67             1                   3
# 38        1023    970922       67             2                   1
# 39        1024    596585       67             3                   1
# 40        1025   2037087       67             4                   2
# 41        1026   2474111       67             5                   3
# 42        1027   1568481       67             6                   3
# 43        1029   2048527       67             8                   2
# 44        1030   2389031       67             9                   2
# 45        1031   2378562       67            10                   1
# 46        1032   1515698       67            11                   1
# 47        1033   1928050       67            12                   2
# 48        1034   1949274       67            13                   1
# 49        1035    551869       67            14                   1
# 50        1037    768572       67            16                   4
# 51        1039    150528       67            18                   5
# 52        1040     29758       67            19                   0
# 53        1042   1558976       67            21                   1
# 54        1043    863974       67            22                   1
# 55        1044   2308399       67            23                   1
# 56        1202   2759128       81             3                   1
# 57        1204   1812985       81             5                   2
# 58        1208   1889835       82             1                   3
# 59        1210    499460       82             3                   5
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                   8                    0.0         196                  1
# 1                   7                   15.0         196                  1
# 2                  12                   21.0         196                  1
# 3                   7                   29.0         196                  1
# 4                  15                   28.0         196                  1
# 5                   7                   19.0         196                  1
# 6                   9                   20.0         196                  1
# 7                  14                   14.0         196                  2
# 8                  16                    0.0         196                  4
# 9                   8                   30.0         196                  1
# 10                  9                    7.0         196                  2
# 11                 16                    8.0         196                  6
# 12                 11                    7.0         196                  1
# 13                  9                    7.0         196                  1
# 14                 10                   14.0         196                  1
# 15                 14                    6.0         196                  3
# 16                 12                    8.0         196                 15
# 17                 17                    6.0         196                  1
# 18                 10                    6.0         196                  2
# 19                  8                    7.0         196                 17
# 20                 11                    8.0         196                 14
# 21                 16                    4.0         196                  9
# 22                 12                    3.0         196                  1
# 23                  9                    0.0         196                  4
# 24                 10                    7.0         196                  5
# 25                 10                    7.0         196                  3
# 26                 10                    8.0         196                  6
# 27                  7                    8.0         196                  5
# 28                 11                    7.0         196                  5
# 29                 10                    8.0         196                  4
# 30                  9                    7.0         196                  3
# 31                 16                    6.0         196                  7
# 32                 11                    8.0         196                  3
# 33                 10                    6.0         196                  4
# 34                 10                   14.0         196                  6
# 35                  8                    8.0         196                  4
# 36                 10                   30.0         196                  1
# 37                 11                    0.0         196                  1
# 38                 15                    5.0         196                  2
# 39                 13                    7.0         196                  2
# 40                  9                    8.0         196                  1
# 41                 14                    8.0         196                  2
# 42                 12                    7.0         196                  2
# 43                 11                    7.0         196                  1
# 44                 14                    7.0         196                  1
# 45                 10                    6.0         196                  1
# 46                 11                    7.0         196                  1
# 47                 12                    8.0         196                  1
# 48                 10                    6.0         196                  1
# 49                  9                    7.0         196                  1
# 50                 10                    9.0         196                  1
# 51                 16                    4.0         196                  1
# 52                 14                    9.0         196                  2
# 53                  9                    5.0         196                  2
# 54                 11                   14.0         196                  3
# 55                 14                   14.0         196                  1
# 56                  9                   14.0         196                  2
# 57                 20                   30.0         196                  1
# 58                 15                    0.0         196                  6
# 59                 10                    5.0         196                  2
#
#     reordered  ... _merge    price_range_loc    busiest_days  \
# 0           0  ...   both  Mid-range product  Regularly busy
# 1           1  ...   both  Mid-range product      Least busy
# 2           1  ...   both  Mid-range product      Least busy
# 3           1  ...   both  Mid-range product      Least busy
# 4           1  ...   both  Mid-range product      Least busy
# 5           1  ...   both  Mid-range product  Regularly busy
# 6           1  ...   both  Mid-range product    Busiest days
# 7           1  ...   both  Mid-range product    Busiest days
# 8           1  ...   both  Mid-range product    Busiest days
# 9           1  ...   both  Mid-range product      Least busy
# 10          0  ...   both  Mid-range product    Busiest days
# 11          1  ...   both  Mid-range product  Regularly busy
# 12          1  ...   both  Mid-range product  Regularly busy
# 13          1  ...   both  Mid-range product    Busiest days
# 14          1  ...   both  Mid-range product    Busiest days
# 15          0  ...   both  Mid-range product  Regularly busy
# 16          1  ...   both  Mid-range product  Regularly busy
# 17          1  ...   both  Mid-range product      Least busy
# 18          0  ...   both  Mid-range product      Least busy
# 19          0  ...   both  Mid-range product      Least busy
# 20          1  ...   both  Mid-range product      Least busy
# 21          0  ...   both  Mid-range product      Least busy
# 22          1  ...   both  Mid-range product      Least busy
# 23          0  ...   both  Mid-range product    Busiest days
# 24          1  ...   both  Mid-range product    Busiest days
# 25          1  ...   both  Mid-range product    Busiest days
# 26          1  ...   both  Mid-range product  Regularly busy
# 27          1  ...   both  Mid-range product  Regularly busy
# 28          1  ...   both  Mid-range product    Busiest days
# 29          1  ...   both  Mid-range product  Regularly busy
# 30          1  ...   both  Mid-range product  Regularly busy
# 31          1  ...   both  Mid-range product    Busiest days
# 32          1  ...   both  Mid-range product  Regularly busy
# 33          1  ...   both  Mid-range product  Regularly busy
# 34          1  ...   both  Mid-range product  Regularly busy
# 35          1  ...   both  Mid-range product      Least busy
# 36          1  ...   both  Mid-range product  Regularly busy
# 37          0  ...   both  Mid-range product      Least busy
# 38          1  ...   both  Mid-range product    Busiest days
# 39          1  ...   both  Mid-range product    Busiest days
# 40          1  ...   both  Mid-range product  Regularly busy
# 41          1  ...   both  Mid-range product      Least busy
# 42          1  ...   both  Mid-range product      Least busy
# 43          1  ...   both  Mid-range product  Regularly busy
# 44          1  ...   both  Mid-range product  Regularly busy
# 45          1  ...   both  Mid-range product    Busiest days
# 46          1  ...   both  Mid-range product    Busiest days
# 47          1  ...   both  Mid-range product  Regularly busy
# 48          1  ...   both  Mid-range product    Busiest days
# 49          1  ...   both  Mid-range product    Busiest days
# 50          1  ...   both  Mid-range product      Least busy
# 51          1  ...   both  Mid-range product  Regularly busy
# 52          1  ...   both  Mid-range product    Busiest days
# 53          1  ...   both  Mid-range product    Busiest days
# 54          1  ...   both  Mid-range product    Busiest days
# 55          1  ...   both  Mid-range product    Busiest days
# 56          0  ...   both  Mid-range product    Busiest days
# 57          1  ...   both  Mid-range product  Regularly busy
# 58          0  ...   both  Mid-range product      Least busy
# 59          1  ...   both  Mid-range product  Regularly busy
#
#     busiest_period_of_day max_order      loyalty_flag average_spend  \
# 0          Average orders        10      New customer      6.367797
# 1          Average orders        10      New customer      6.367797
# 2             Most orders        10      New customer      6.367797
# 3          Average orders        10      New customer      6.367797
# 4             Most orders        10      New customer      6.367797
# 5          Average orders        10      New customer      6.367797
# 6             Most orders        10      New customer      6.367797
# 7             Most orders        10      New customer      6.367797
# 8             Most orders        10      New customer      6.367797
# 9          Average orders        10      New customer      6.367797
# 10            Most orders        22  Regular customer      3.980556
# 11            Most orders        22  Regular customer      3.980556
# 12            Most orders        22  Regular customer      3.980556
# 13            Most orders        22  Regular customer      3.980556
# 14            Most orders        22  Regular customer      3.980556
# 15            Most orders         9      New customer      8.372059
# 16            Most orders         9      New customer      8.372059
# 17            Most orders         9      New customer      8.372059
# 18            Most orders        33  Regular customer      7.012683
# 19         Average orders        20  Regular customer      8.137793
# 20            Most orders        20  Regular customer      8.137793
# 21            Most orders        11  Regular customer      7.444898
# 22            Most orders        11  Regular customer      7.444898
# 23            Most orders        27  Regular customer      6.356287
# 24            Most orders        27  Regular customer      6.356287
# 25            Most orders        27  Regular customer      6.356287
# 26            Most orders        27  Regular customer      6.356287
# 27         Average orders        27  Regular customer      6.356287
# 28            Most orders        27  Regular customer      6.356287
# 29            Most orders        27  Regular customer      6.356287
# 30            Most orders        27  Regular customer      6.356287
# 31            Most orders        27  Regular customer      6.356287
# 32            Most orders        27  Regular customer      6.356287
# 33            Most orders        27  Regular customer      6.356287
# 34            Most orders        27  Regular customer      6.356287
# 35         Average orders        27  Regular customer      6.356287
# 36            Most orders        27  Regular customer      6.356287
# 37            Most orders        24  Regular customer      7.656790
# 38            Most orders        24  Regular customer      7.656790
# 39            Most orders        24  Regular customer      7.656790
# 40            Most orders        24  Regular customer      7.656790
# 41            Most orders        24  Regular customer      7.656790
# 42            Most orders        24  Regular customer      7.656790
# 43            Most orders        24  Regular customer      7.656790
# 44            Most orders        24  Regular customer      7.656790
# 45            Most orders        24  Regular customer      7.656790
# 46            Most orders        24  Regular customer      7.656790
# 47            Most orders        24  Regular customer      7.656790
# 48            Most orders        24  Regular customer      7.656790
# 49            Most orders        24  Regular customer      7.656790
# 50            Most orders        24  Regular customer      7.656790
# 51            Most orders        24  Regular customer      7.656790
# 52            Most orders        24  Regular customer      7.656790
# 53            Most orders        24  Regular customer      7.656790
# 54            Most orders        24  Regular customer      7.656790
# 55            Most orders        24  Regular customer      7.656790
# 56            Most orders         7      New customer      8.165385
# 57         Average orders         7      New customer      8.165385
# 58            Most orders        19  Regular customer      6.441221
# 59            Most orders        19  Regular customer      6.441221
#
#    spending_type  median_order_days        order_frequency
# 0    Low spender               20.0       Regular customer
# 1    Low spender               20.0       Regular customer
# 2    Low spender               20.0       Regular customer
# 3    Low spender               20.0       Regular customer
# 4    Low spender               20.0       Regular customer
# 5    Low spender               20.0       Regular customer
# 6    Low spender               20.0       Regular customer
# 7    Low spender               20.0       Regular customer
# 8    Low spender               20.0       Regular customer
# 9    Low spender               20.0       Regular customer
# 10   Low spender                8.0      Frequent customer
# 11   Low spender                8.0      Frequent customer
# 12   Low spender                8.0      Frequent customer
# 13   Low spender                8.0      Frequent customer
# 14   Low spender                8.0      Frequent customer
# 15   Low spender                6.0      Frequent customer
# 16   Low spender                6.0      Frequent customer
# 17   Low spender                6.0      Frequent customer
# 18   Low spender                7.0      Frequent customer
# 19   Low spender                6.0      Frequent customer
# 20   Low spender                6.0      Frequent customer
# 21   Low spender               10.0      Frequent customer
# 22   Low spender               10.0      Frequent customer
# 23   Low spender                8.0      Frequent customer
# 24   Low spender                8.0      Frequent customer
# 25   Low spender                8.0      Frequent customer
# 26   Low spender                8.0      Frequent customer
# 27   Low spender                8.0      Frequent customer
# 28   Low spender                8.0      Frequent customer
# 29   Low spender                8.0      Frequent customer
# 30   Low spender                8.0      Frequent customer
# 31   Low spender                8.0      Frequent customer
# 32   Low spender                8.0      Frequent customer
# 33   Low spender                8.0      Frequent customer
# 34   Low spender                8.0      Frequent customer
# 35   Low spender                8.0      Frequent customer
# 36   Low spender                8.0      Frequent customer
# 37   Low spender                7.0      Frequent customer
# 38   Low spender                7.0      Frequent customer
# 39   Low spender                7.0      Frequent customer
# 40   Low spender                7.0      Frequent customer
# 41   Low spender                7.0      Frequent customer
# 42   Low spender                7.0      Frequent customer
# 43   Low spender                7.0      Frequent customer
# 44   Low spender                7.0      Frequent customer
# 45   Low spender                7.0      Frequent customer
# 46   Low spender                7.0      Frequent customer
# 47   Low spender                7.0      Frequent customer
# 48   Low spender                7.0      Frequent customer
# 49   Low spender                7.0      Frequent customer
# 50   Low spender                7.0      Frequent customer
# 51   Low spender                7.0      Frequent customer
# 52   Low spender                7.0      Frequent customer
# 53   Low spender                7.0      Frequent customer
# 54   Low spender                7.0      Frequent customer
# 55   Low spender                7.0      Frequent customer
# 56   Low spender               30.0  Non-frequent customer
# 57   Low spender               30.0  Non-frequent customer
# 58   Low spender               11.0       Regular customer
# 59   Low spender               11.0       Regular customer
#
# [60 rows x 24 columns]

# %% [markdown]
# # Exporting final dataframe

# %%
# export data to pkl

ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products.pkl'))
